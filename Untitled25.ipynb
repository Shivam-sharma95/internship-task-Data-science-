# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-23b71130-c6c6-418f-a607-1f107e76675f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-23b71130-c6c6-418f-a607-1f107e76675f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_excel("/content/remoteok_700_jobs (2) excel.xlsx")
df.head()
# Out:
#                                            Job Title          Company Name  \
# 0                $1k Weekly Work from Home Assistant     Best Estimate Pro
# 1                   Coding Bootcampï¿½ï¿½ï¿½Job Guar                Metana
# 2  Senior Engineer Confluent Marketplace Partner ...             Confluent
# 3                   Senior Product Designer Tï¿½ï¿½r             JumpCloud
# 4                   Manager User Group Program 11132  Coupa Software, Inc.
#
#                                              Job URL  \
# 0  https://remoteok.com/remote-jobs/remote-1k-wee...
# 1  https://remoteok.com/remote-jobs/remote-coding...
# 2  https://remoteok.com/remote-jobs/remote-senior...
# 3  https://remoteok.com/remote-jobs/remote-senior...
# 4  https://remoteok.com/remote-jobs/remote-manage...
#
#                                             Job Tags  \
# 0                                   Customer Support
# 1  No Tech Background Needed, Job or 100% Money Back
# ...

# %%
df = df.drop_duplicates()

# %%
df = df.dropna()

# %%
df = df.fillna("Not Available")

# %%
df.columns
# column name
# Out:
# Index(['Job Title', 'Company Name', 'Job URL', 'Job Tags', 'Salary Range',
#        'Date Posted', 'Location'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower().str.strip()
df.columns
#Column names clean karo
# Out:
# Index(['job title', 'company name', 'job url', 'job tags', 'salary range',
#        'date posted', 'location'],
#       dtype='object')

# %%
#df = df.drop(columns=['job url', 'job tags'], errors='ignore')
#Unnecessary columns remove karo

# %%
df = df.drop_duplicates()
#Duplicate rows remove

# %%
df.isnull().sum()
#Null / missing values handle karo
# Out:
# job title       0
# company name    0
# job url         0
# job tags        0
# salary range    0
# date posted     0
# location        0
# dtype: int64

# %%
df = df.dropna(subset=['job title', 'company name'])
#Remove rows jahan important data missing ho

# %%
df['salary range'] = df['salary range'].fillna('Not Disclosed')
#Salary column clean

# %%
df['date posted'] = pd.to_datetime(df['date posted'], errors='coerce')
# Date column proper format me

# %%
from google.colab import files

df.to_excel('cleaned_jobs_data.xlsx', index=False)
files.download('cleaned_jobs_data.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2088795103.py in <cell line: 0>()
#       1 from google.colab import files
#       2
# ----> 3 df.to_excel('cleaned_jobs_data.xlsx', index=False)
#       4 files.download('cleaned_jobs_data.xlsx')
#
# /usr/local/lib/python3.12/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#     334
#     335         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
# ...
