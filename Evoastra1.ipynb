# %%
from  bs4 import BeautifulSoup
import requests
import pandas as pd
import warning

# %%
url = 'https://remoteok.com/'

# %%
page= requests.get(url)

# %%
soup = BeautifulSoup(page.text,'html')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="pageType-frontpage remoteok minimize-header catch-emails-enabled" lang="en">
#  <head>
#   <link href="/global.css?1761481057" rel="stylesheet"/>
#   <script>
#    var userIsAdmin=false;
#   </script>
#   <meta charset="utf-8"/>
#   <title>
#    Remote Jobs in Programming, Design, Sales and more #OpenSalaries
#   </title>
#   <meta content="Looking for a remote job? Remote OK® is the #1 Remote Job Platform and has 1,129,838+ remote jobs as a Developer, Designer, Copywriter, Customer Support Rep, Sales Professional, Project Manager and more! Find a career where you can work remotely from anywhere." name="description"/>
#   <meta content="5E0F32F90CCE5417B26666C526F8B071" name="msvalidate.01"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="en-US" http-equiv="Content-Language"/>
#   <link href="/opensearch.xml" rel="search" title="Remote OK" type="application/opensearchdescription+xml"/>
# ...

# %%
soup.find('div')
# Out:
# <div class="catch-emails" data-tag="">
# <div class="form">
# <p>
# 								Get new remote jobs sent to<input id="mce-JOBTYPE" name="JOBTYPE" type="hidden" value="jobs"/>
# </p><span class="mobile"></span>
# <input class="email" placeholder="Type your email..." type="text"/>
# <input class="source" type="hidden" value=""/>
# <input class="tag" style="margin-right:0" type="hidden" value=""/>
# <div class="button action-subscribe">Subscribe</div>
# <div class="action-close-catch-emails">
# 				×
# 			</div>
# <script>
# 				var recaptchaLoaded=false;
#
# 				$(function() {
#
# 					$('.catch-emails .email').bind('keyup',function(e) {
# 						if(!recaptchaLoaded) {
# 							$('html').append('<script src="https://www.google.com/recaptcha/api.js?render=6Ld_BecUAAAAAAxzQwBa6NY3-m5RDmjVY__ScSww&onload=recaptchaCallback" async defer>'+decodeURI('%3C/script%3E'));
# 							recaptchaLoaded=true;
# 						}
# 						if(!recaptchaLoaded && e.which==13) {
# 							setTimeout(function() {
# ...

# %%
soup.find_all('div')
# Out:
# [<div class="catch-emails" data-tag="">
#  <div class="form">
#  <p>
#  								Get new remote jobs sent to<input id="mce-JOBTYPE" name="JOBTYPE" type="hidden" value="jobs"/>
#  </p><span class="mobile"></span>
#  <input class="email" placeholder="Type your email..." type="text"/>
#  <input class="source" type="hidden" value=""/>
#  <input class="tag" style="margin-right:0" type="hidden" value=""/>
#  <div class="button action-subscribe">Subscribe</div>
#  <div class="action-close-catch-emails">
#  				×
#  			</div>
#  <script>
#  				var recaptchaLoaded=false;
#
#  				$(function() {
#
#  					$('.catch-emails .email').bind('keyup',function(e) {
#  						if(!recaptchaLoaded) {
#  							$('html').append('<script src="https://www.google.com/recaptcha/api.js?render=6Ld_BecUAAAAAAxzQwBa6NY3-m5RDmjVY__ScSww&onload=recaptchaCallback" async defer>'+decodeURI('%3C/script%3E'));
#  							recaptchaLoaded=true;
#  						}
#  						if(!recaptchaLoaded && e.which==13) {
# ...

# %%
soup.find_all('div',class_ = '')
# Out:
# [<div style="float:left;font-weight:bold;margin-bottom:7px;">
#  							Minimum
#  						</div>,
#  <div style="float:right;margin-bottom:7px;">
#  															$<span class="salary-filter-input-amount">0</span>k/year
#  													</div>,
#  <div style="clear:both"></div>,
#  <div data-benefit="401k">
#  									💰 401(k)							</div>,
#  <div data-benefit="distributed_team">
#  									🌎 Distributed team							</div>,
#  <div data-benefit="async">
#  									⏰ Async							</div>,
#  <div data-benefit="vision_insurance">
#  									🤓 Vision insurance							</div>,
#  <div data-benefit="dental_insurance">
#  									🦷 Dental insurance							</div>,
#  <div data-benefit="medical_insurance">
#  									🚑 Medical insurance							</div>,
#  <div data-benefit="unlimited_vacation">
#  									🏖 Unlimited vacation							</div>,
#  <div data-benefit="paid_time_off">
#  									🏖 Paid time off							</div>,
#  <div data-benefit="4_day_workweek">
# ...

# %%
soup.find_all('th' , class_ = 'filter-actions')
# Out:
# [<th class="filter-actions" colspan="10" style="padding:0;">
#  <div class="top-bar-avatar">
#  <img class="top-bar-avatar-img" src="https://remoteok.com/assets/logo-square.png"/>
#  </div>
#  <span class="dropdown-toggle"></span>
#  <div class="search-filter">
#  <input autocomplete="google_chrome_fix" class="search-filter-input" placeholder="🔍 Search" type="text" value=""/>
#  <div class="search-filter-input-icon-circle">
#  <div class="search-filter-input-icon"></div>
#  </div>
#  </div>
#  <div class="location-filter">
#  <input autocomplete="google_chrome_fix" class="location-filter-input" placeholder="🌏 Location" type="text"/>
#  <div class="location-filter-icon-circle">
#  <div class="location-filter-icon"></div>
#  </div>
#  </div>
#  <div class="salary-filter">
#  <div>
#  												💵 Salary
#  											</div>
#  <div class="salary-filter-icon-circle">
#  <div class="salary-filter-icon"></div>
#  </div>
#  </div>
#  <div class="benefits-filter">
#  <div>
# ...

# %%
world_titles = soup.find('th' , class_ = 'filter-actions').text

# %%
world_titles
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t💵 Salary\n\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t🎪 Benefits\n\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n\n\n🦴 Sort by\n🆕 Latest jobs\n💵 Highest paid\n👀 Most viewed\n✅ Most applied\n🔥 Hottest\n🎪 Most benefits\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t❌ Clear 1 results\t\t\t\t\t\t\t\t\t\t\t\n\n'

# %%
world_table_titles =soup.find('th', class_ = 'filter-actions').text.strip()

# %%
print(world_table_titles)
# Out:
# 💵 Salary
#
#
#
#
#
#
#
# 												🎪 Benefits
#
#
#
#
#
#
# 🦴 Sort by
# 🆕 Latest jobs
# 💵 Highest paid
# 👀 Most viewed
# ✅ Most applied
# 🔥 Hottest
# 🎪 Most benefits
#
#
#
# 												❌ Clear 1 results

# %%
soup.find_all('h3')
# Out:
# []

# %%
soup.find_all('h2')
# Out:
# []

# %%
world_titles = soup.find_all('h3')

# %% [raw]
# world_titles
